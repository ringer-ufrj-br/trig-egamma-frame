# %% [markdown]
# # How to collect Run 3 data?

# %%
import numpy as np

from trig_egamma_frame import ElectronLoop, DataframeSchemma, EventContext, GeV, ToolSvc
from trig_egamma_frame.algorithms.dumper import ElectronDumper_v2 as ElectronDumper
from trig_egamma_frame.algorithms import Filter, EventFilter, isAny_decorator, isZ_decorator, isJpsi_decorator
from trig_egamma_frame.algorithms import Efficiency, Quadrant
# Out:
# Welcome to JupyROOT 6.30/04
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776958152.593394  776619 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1776958152.595241  776619 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1776958152.659328  776619 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776958157.017206  776619 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1776958157.018344  776619 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
input_files = "/mnt/shared/storage03/projects/cern/data/mc21_13p6TeV/no_restrictions/user.isilvafe.mc21_13p6TeV.Zee.AOD.r14136_2sigma_constraint_26.10.23_v0_EXT0.tap_zee_5M_XYZ.root.tgz/*.root"
output = 'test'
et_bins  = [3., 7., 10., 15., 20., 30., 40., 50., 1000000.]
eta_bins = [0.0, 0.8, 1.37, 1.54, 2.37, 2.50]
triggers = [
   "HLT_e28_lhtight_nod0_noringer_ivarloose_eEM24VHI",
   "HLT_e28_lhtight_nod0_ringer_v1_ivarloose_eEM24VHI",
]

# %%
acc = ElectronLoop(  "EventATLASLoop",
                         inputFile  = input_files,
                         #treePath   = "*/HLT/Physval/Egamma/probes",
                         treePath  =  "*/HLT/EgammaMon/summary/events",
                         dataframe  = DataframeSchemma.Run3,
                         outputFile = "output.root",
                         abort = True,
                      )

ToolSvc+=Filter( "Filter", [EventFilter(is_data=True, is_background=False)])

# %%
#dumper = ElectronDumper(output, et_bins, eta_bins)
#for trigName in triggers:
#    dumper.decorate_chain(trigName)
#dumper.decorate( "mc_isTruthElectronFromZ"          , isZ_decorator   )
#dumper.decorate( "mc_isTruthElectronFromAny"        , isAny_decorator )
#dumper.decorate( "mc_isTruthElectronFromJpsiPromt"  , isJpsi_decorator)
#is_background=False
#def is_target( ctx : EventContext ) -> np.int32:
#    return np.int32(0) if is_background else np.int32(1)
#dumper.decorate( "target", is_target)
#ToolSvc+=dumper

# %%
ToolSvc+=Efficiency("Efficiency", triggers=triggers)


quadrant = Quadrant("Quadrant")

quadrant.add_feature(
    "HLT_e28_lhtight_nod0_noringer_ivarloose_eEM24VHI",
    "HLT_e28_lhtight_nod0_ringer_v1_ivarloose_eEM24VHI",
)


ToolSvc+=quadrant
# Out:
# {'FSinfo': '',
#  'IDinfo': 'lhtight',
#  'IDinfoType': '',
#  'L1Legacy': False,
#  'L1Threshold': 'eEM24VHI',
#  'L1threshold': '',
#  'L2IDAlg': 'noringer',
#  'addInfo': [],
#  'alignmentGroup': ['Electron'],
#  'caloInfo': '',
#  'etaRange': '0eta250',
#  'extra': '',
#  'gsfInfo': '',
#  'hypoInfo': '',
#  'idperfInfo': '',
#  'isoInfo': 'ivarloose',
#  'lhInfo': 'nod0',
#  'lrtInfo': '',
#  'multiplicity': '',
#  'reccalibInfo': '',
#  'recoAlg': '',
#  'ringerVersion': 'run3_v1',
#  'sigFolder': ['Egamma'],
#  'signature': 'Electron',
#  'subSigs': ['Electron'],
#  'threshold': 28.0,
#  'tnpInfo': '',
#  'topo': [],
#  'trigName': 'HLT_e28_lhtight_nod0_noringer_ivarloose_eEM24VHI',
#  'trigType': 'e'}
# 23-Apr-2026 12:29:24 | Signature :e
# 23-Apr-2026 12:29:24 | Threshold :28.0
# 23-Apr-2026 12:29:24 | Pidname   :lhtight
# 23-Apr-2026 12:29:24 | noringerinfo :noringer
# 23-Apr-2026 12:29:24 | Configure noringer
# 23-Apr-2026 12:29:24 | Threshold :28.0
# 23-Apr-2026 12:29:24 | Pidname   :lhtight
# 23-Apr-2026 12:29:24 | Configure nominal...
# 23-Apr-2026 12:29:24 | Electron_Threshold :28.0
# 23-Apr-2026 12:29:24 | Electron_Pidname   :lhtight
# 23-Apr-2026 12:29:24 | Electron_iso       :ivarloose
# 23-Apr-2026 12:29:24 | Electron_d0        :
# 23-Apr-2026 12:29:24 | Adding IsoCut...
# {'FSinfo': '',
#  'IDinfo': 'lhtight',
#  'IDinfoType': '',
#  'L1Legacy': False,
#  'L1Threshold': 'eEM24VHI',
#  'L1threshold': '',
#  'L2IDAlg': '',
#  'addInfo': [],
#  'alignmentGroup': ['Electron'],
#  'caloInfo': '',
#  'etaRange': '0eta250',
#  'extra': '',
#  'gsfInfo': '',
#  'hypoInfo': '',
#  'idperfInfo': '',
#  'isoInfo': 'ivarloose',
#  'lhInfo': 'nod0',
#  'lrtInfo': '',
#  'multiplicity': '',
#  'reccalibInfo': '',
#  'recoAlg': '',
#  'ringerVersion': 'run3_v1',
#  'sigFolder': ['Egamma'],
#  'signature': 'Electron',
#  'subSigs': ['Electron'],
#  'threshold': 28.0,
#  'tnpInfo': '',
#  'topo': [],
#  'trigName': 'HLT_e28_lhtight_nod0_ringer_v1_ivarloose_eEM24VHI',
#  'trigType': 'e'}
# 23-Apr-2026 12:29:24 | Signature :e
# 23-Apr-2026 12:29:24 | Threshold :28.0
# 23-Apr-2026 12:29:24 | Pidname   :lhtight
# 23-Apr-2026 12:29:24 | noringerinfo :
# 23-Apr-2026 12:29:24 | Configure ringer
# 23-Apr-2026 12:29:24 | Threshold :28.0
# 23-Apr-2026 12:29:24 | Pidname   :lhtight
# 23-Apr-2026 12:29:24 | Configure nominal...
# 23-Apr-2026 12:29:24 | Electron_Threshold :28.0
# 23-Apr-2026 12:29:24 | Electron_Pidname   :lhtight
# 23-Apr-2026 12:29:24 | Electron_iso       :ivarloose
# 23-Apr-2026 12:29:24 | Electron_d0        :
# 23-Apr-2026 12:29:24 | Adding IsoCut...

# %%
acc.run(50)
# Out:
# 23-Apr-2026 12:29:24 | Initializing Event...
# 23-Apr-2026 12:29:24 | Iiitializing TEventLoop...
# creating collection tree : 100%|██████████████████████████████████████████████████████████████████| 496/496 [00:02<00:00, 231.47it/s]
# 23-Apr-2026 12:29:28 | creating StoreGate...
# 23-Apr-2026 12:29:28 | Creating containers...
# 23-Apr-2026 12:29:28 | Initialize the dataframe with name: EventInfoContainer
# 23-Apr-2026 12:29:28 | Initialize the dataframe with name: MonteCarloContainer
# 23-Apr-2026 12:29:28 | Initialize the dataframe with name: CaloClusterContainer
# 23-Apr-2026 12:29:28 | Initialize the dataframe with name: MenuContainer
# 23-Apr-2026 12:29:28 | Initialize the dataframe with name: HLT__TrigEMClusterContainer
# 23-Apr-2026 12:29:28 | Initialize the dataframe with name: HLT__CaloClusterContainer
# 23-Apr-2026 12:29:28 | Initialize the dataframe with name: HLT__EmTauRoIContainer
# 23-Apr-2026 12:29:28 | Initialize the dataframe with name: ElectronContainer
# 23-Apr-2026 12:29:28 | Initialize the dataframe with name: TrackParticleContainer
# 23-Apr-2026 12:29:28 | Initialize the dataframe with name: HLT__TrigElectronContainer
# 23-Apr-2026 12:29:28 | Initialize the dataframe with name: HLT__ElectronContainer
# 23-Apr-2026 12:29:28 | Initialize the dataframe with name: HLT__TrackParticleContainer
# 23-Apr-2026 12:29:28 | Initializing all tools...
# 23-Apr-2026 12:29:28 | Initializing HLT_e28_lhtight_nod0_noringer_ivarloose_eEM24VHI chain
# 23-Apr-2026 12:29:28 | Initializing HLT_e28_lhtight_nod0_ringer_v1_ivarloose_eEM24VHI chain
# 23-Apr-2026 12:29:28 | Loading ringer models from /mnt/shared/storage03/projects/cern/data/tunings/release/trigger/Run3_20230316_v1/ElectronRingerTightTriggerConfig.conf
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 23-Apr-2026 12:29:29 | Initializing Efficiency...
# 23-Apr-2026 12:29:29 | Initializing Quadrant...
# looping over entries :   0%|                                                                                  | 0/50 [00:00<?, ?it/s]/home/joao.pinto/miniconda3/envs/trig-egamma-frame/lib/python3.10/site-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['Input']
# Received: inputs=Tensor(shape=(1, 50))
#   warnings.warn(msg)
# looping over entries : 100%|████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 124.30it/s]
# 23-Apr-2026 12:29:30 | Finalizing all tools...
# 23-Apr-2026 12:29:30 | Finalizing HLT_e28_lhtight_nod0_noringer_ivarloose_eEM24VHI chain
# 23-Apr-2026 12:29:30 | Finalizing HLT_e28_lhtight_nod0_ringer_v1_ivarloose_eEM24VHI chain
# 23-Apr-2026 12:29:30 | ---------------HLT_e28_lhtight_nod0_noringer_ivarloose_eEM24VHI---------------
# 23-Apr-2026 12:29:30 | | L1Calo                         | 100.00   (34   , 34   ) |
# 23-Apr-2026 12:29:30 | | FastCalo                       | 100.00   (34   , 34   ) |
# 23-Apr-2026 12:29:30 | | FastElectron                   | 100.00   (34   , 34   ) |
# 23-Apr-2026 12:29:30 | | PrecisionCalo                  | 100.00   (34   , 34   ) |
# 23-Apr-2026 12:29:30 | | PrecisionElectron              | 88.24    (30   , 34   ) |
# 23-Apr-2026 12:29:30 | ------------------------------------------------------------------------------
# 23-Apr-2026 12:29:30 | --------------HLT_e28_lhtight_nod0_ringer_v1_ivarloose_eEM24VHI---------------
# 23-Apr-2026 12:29:30 | | L1Calo                         | 100.00   (34   , 34   ) |
# 23-Apr-2026 12:29:30 | | FastCalo                       | 100.00   (34   , 34   ) |
# 23-Apr-2026 12:29:30 | | FastElectron                   | 100.00   (34   , 34   ) |
# 23-Apr-2026 12:29:30 | | PrecisionCalo                  | 100.00   (34   , 34   ) |
# 23-Apr-2026 12:29:30 | | PrecisionElectron              | 88.24    (30   , 34   ) |
# 23-Apr-2026 12:29:30 | ------------------------------------------------------------------------------
# 23-Apr-2026 12:29:30 | Finalizing StoreGate service...
# 23-Apr-2026 12:29:30 | writting root data into output.root
# E0000 00:00:1776958168.433985  776619 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
