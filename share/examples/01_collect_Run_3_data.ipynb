# %% [markdown]
# # How to collect Run 3 data?

# %%
import numpy as np

from trig_egamma_frame import ElectronLoop, DataframeSchemma, EventContext, GeV, ToolSvc
from trig_egamma_frame.algorithms.dumper import ElectronDumper_v2 as ElectronDumper
from trig_egamma_frame.algorithms import Filter, EventFilter, isAny_decorator, isZ_decorator, isJpsi_decorator
from trig_egamma_frame.algorithms import Efficiency, Quadrant
# Out:
# Welcome to JupyROOT 6.30/04
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776370193.803144 3773837 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1776370193.805147 3773837 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1776370193.872724 3773837 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776370195.889961 3773837 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1776370195.891318 3773837 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
input_files = "/mnt/shared/storage03/projects/cern/data/mc21_13p6TeV/no_restrictions/user.isilvafe.mc21_13p6TeV.Zee.AOD.r14136_2sigma_constraint_26.10.23_v0_EXT0.tap_zee_5M_XYZ.root.tgz/*.root"
output = 'test'
et_bins  = [3., 7., 10., 15., 20., 30., 40., 50., 1000000.]
eta_bins = [0.0, 0.8, 1.37, 1.54, 2.37, 2.50]
triggers = [
   "HLT_e28_lhtight_nod0_noringer_ivarloose_eEM24VHI",
   "HLT_e28_lhtight_nod0_ringer_v1_ivarloose_eEM24VHI",
]

# %%
acc = ElectronLoop(  "EventATLASLoop",
                         inputFile  = input_files,
                         #treePath   = "*/HLT/Physval/Egamma/probes",
                         treePath  =  "*/HLT/EgammaMon/summary/events",
                         dataframe  = DataframeSchemma.Run3,
                         outputFile = "output.root",
                         abort = True,
                      )

ToolSvc+=Filter( "Filter", [EventFilter(is_data=True, is_background=False)])

# %%
#dumper = ElectronDumper(output, et_bins, eta_bins)
#for trigName in triggers:
#    dumper.decorate_chain(trigName)
#dumper.decorate( "mc_isTruthElectronFromZ"          , isZ_decorator   )
#dumper.decorate( "mc_isTruthElectronFromAny"        , isAny_decorator )
#dumper.decorate( "mc_isTruthElectronFromJpsiPromt"  , isJpsi_decorator)
#is_background=False
#def is_target( ctx : EventContext ) -> np.int32:
#    return np.int32(0) if is_background else np.int32(1)
#dumper.decorate( "target", is_target)
#ToolSvc+=dumper

# %%
ToolSvc+=Efficiency("Efficiency", triggers=triggers)


quadrant = Quadrant("Quadrant")

quadrant.add_feature(
    "HLT_e28_lhtight_nod0_noringer_ivarloose_eEM24VHI",
    "HLT_e28_lhtight_nod0_ringer_v1_ivarloose_eEM24VHI"
)


ToolSvc+=quadrant
# Out:
# {'FSinfo': '',
#  'IDinfo': 'lhtight',
#  'IDinfoType': '',
#  'L1Legacy': False,
#  'L1Threshold': 'eEM24VHI',
#  'L1threshold': '',
#  'L2IDAlg': 'noringer',
#  'addInfo': [],
#  'alignmentGroup': ['Electron'],
#  'caloInfo': '',
#  'etaRange': '0eta250',
#  'extra': '',
#  'gsfInfo': '',
#  'hypoInfo': '',
#  'idperfInfo': '',
#  'isoInfo': 'ivarloose',
#  'lhInfo': 'nod0',
#  'lrtInfo': '',
#  'multiplicity': '',
#  'reccalibInfo': '',
#  'recoAlg': '',
#  'ringerVersion': 'run3_v1',
#  'sigFolder': ['Egamma'],
#  'signature': 'Electron',
#  'subSigs': ['Electron'],
#  'threshold': 28.0,
#  'tnpInfo': '',
#  'topo': [],
#  'trigName': 'HLT_e28_lhtight_nod0_noringer_ivarloose_eEM24VHI',
#  'trigType': 'e'}
# 16-Apr-2026 17:09:59 | Signature :e
# 16-Apr-2026 17:09:59 | Threshold :28.0
# 16-Apr-2026 17:09:59 | Pidname   :lhtight
# 16-Apr-2026 17:09:59 | noringerinfo :noringer
# 16-Apr-2026 17:09:59 | Configure noringer
# 16-Apr-2026 17:09:59 | Threshold :28.0
# 16-Apr-2026 17:09:59 | Pidname   :lhtight
# 16-Apr-2026 17:09:59 | Configure nominal...
# 16-Apr-2026 17:09:59 | Electron_Threshold :28.0
# 16-Apr-2026 17:09:59 | Electron_Pidname   :lhtight
# 16-Apr-2026 17:09:59 | Electron_iso       :ivarloose
# 16-Apr-2026 17:09:59 | Electron_d0        :
# 16-Apr-2026 17:09:59 | Adding IsoCut...
# {'FSinfo': '',
#  'IDinfo': 'lhtight',
#  'IDinfoType': '',
#  'L1Legacy': False,
#  'L1Threshold': 'eEM24VHI',
#  'L1threshold': '',
#  'L2IDAlg': '',
#  'addInfo': [],
#  'alignmentGroup': ['Electron'],
#  'caloInfo': '',
#  'etaRange': '0eta250',
#  'extra': '',
#  'gsfInfo': '',
#  'hypoInfo': '',
#  'idperfInfo': '',
#  'isoInfo': 'ivarloose',
#  'lhInfo': 'nod0',
#  'lrtInfo': '',
#  'multiplicity': '',
#  'reccalibInfo': '',
#  'recoAlg': '',
#  'ringerVersion': 'run3_v1',
#  'sigFolder': ['Egamma'],
#  'signature': 'Electron',
#  'subSigs': ['Electron'],
#  'threshold': 28.0,
#  'tnpInfo': '',
#  'topo': [],
#  'trigName': 'HLT_e28_lhtight_nod0_ringer_v1_ivarloose_eEM24VHI',
#  'trigType': 'e'}
# 16-Apr-2026 17:09:59 | Signature :e
# 16-Apr-2026 17:09:59 | Threshold :28.0
# 16-Apr-2026 17:09:59 | Pidname   :lhtight
# 16-Apr-2026 17:09:59 | noringerinfo :
# 16-Apr-2026 17:09:59 | Configure ringer
# 16-Apr-2026 17:09:59 | Threshold :28.0
# 16-Apr-2026 17:09:59 | Pidname   :lhtight
# 16-Apr-2026 17:09:59 | Configure nominal...
# 16-Apr-2026 17:09:59 | Electron_Threshold :28.0
# 16-Apr-2026 17:09:59 | Electron_Pidname   :lhtight
# 16-Apr-2026 17:09:59 | Electron_iso       :ivarloose
# 16-Apr-2026 17:09:59 | Electron_d0        :
# 16-Apr-2026 17:09:59 | Adding IsoCut...

# %%
acc.run(5000)
# Out:
# 16-Apr-2026 17:10:00 | Initializing Event...
# 16-Apr-2026 17:10:00 | Iiitializing TEventLoop...
# creating collection tree : 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 496/496 [00:02<00:00, 214.36it/s]
# 16-Apr-2026 17:10:03 | creating StoreGate...
# 16-Apr-2026 17:10:03 | Creating containers...
# 16-Apr-2026 17:10:03 | Initialize the dataframe with name: EventInfoContainer
# 16-Apr-2026 17:10:03 | Initialize the dataframe with name: MonteCarloContainer
# 16-Apr-2026 17:10:03 | Initialize the dataframe with name: CaloClusterContainer
# 16-Apr-2026 17:10:03 | Initialize the dataframe with name: MenuContainer
# 16-Apr-2026 17:10:03 | Initialize the dataframe with name: HLT__TrigEMClusterContainer
# 16-Apr-2026 17:10:03 | Initialize the dataframe with name: HLT__CaloClusterContainer
# 16-Apr-2026 17:10:03 | Initialize the dataframe with name: HLT__EmTauRoIContainer
# 16-Apr-2026 17:10:03 | Initialize the dataframe with name: ElectronContainer
# 16-Apr-2026 17:10:03 | Initialize the dataframe with name: TrackParticleContainer
# 16-Apr-2026 17:10:03 | Initialize the dataframe with name: HLT__TrigElectronContainer
# 16-Apr-2026 17:10:03 | Initialize the dataframe with name: HLT__ElectronContainer
# 16-Apr-2026 17:10:03 | Initialize the dataframe with name: HLT__TrackParticleContainer
# 16-Apr-2026 17:10:03 | Initializing all tools...
# 16-Apr-2026 17:10:03 | Initializing HLT_e28_lhtight_nod0_noringer_ivarloose_eEM24VHI chain
# 16-Apr-2026 17:10:03 | Initializing HLT_e28_lhtight_nod0_ringer_v1_ivarloose_eEM24VHI chain
# 16-Apr-2026 17:10:03 | Loading ringer models from "/mnt/shared/storage03/projects/cern/data"/tunings/release/trigger/Run3_20230316_v1/ElectronRingerTightTriggerConfig.conf
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 acc.run(5000)
#
# File ~/git_repos/trig-egamma-frame/trig_egamma_frame/kernel/TEventLoop.py:233, in TEventLoop.run(self, nov)
#     231 def run( self, nov: int = -1 ) -> None:
#     232   self._nov = nov
# --> 233   self.initialize()
#     234   self.execute()
#     235   self.finalize()
#
# File ~/git_repos/trig-egamma-frame/trig_egamma_frame/event.py:157, in ElectronLoop.initialize(self)
#     155   if alg.isInitialized():
#     156     continue
# --> 157   if alg.initialize().isFailure():
#     158     logger.error( "Impossible to initialize the tool name: %s",alg.name)
#     160 return StatusCode.SUCCESS
#
# File ~/git_repos/trig-egamma-frame/trig_egamma_frame/emulator/Emulator.py:63, in Emulator.initialize(self)
#      61 for chain in self.chains.values():
#      62   logger.info( f'Initializing {chain.name()} chain')
# ---> 63   if chain.initialize().isFailure():
#      64     logger.error( f'Can not initialize {chain.name()}')
#      66 return StatusCode.SUCCESS
#
# File ~/git_repos/trig-egamma-frame/trig_egamma_frame/emulator/run3/menu/ElectronChain.py:196, in ElectronChain.initialize(self)
#     194 def initialize(self) -> StatusCode:
#     195   for hypo in self.hypos:
# --> 196     if hypo.initialize().isFailure():
#     197       logger.error(f"Its not possible to initialize {hypo.name}")
#     198       return StatusCode.FAILURE
#
# File ~/git_repos/trig-egamma-frame/trig_egamma_frame/emulator/run3/electron/step1_hypo.py:110, in L2Calo.initialize(self)
#     108 logger.info( f"Loading ringer models from {self.ConfigPath}")
#     109 self.ringer = RingerSelector(ConfigPath=self.ConfigPath)
# --> 110 if self.ringer.initialize().isFailure():
#     111     logger.error( "Its not possible to initialize the ringer selector.")
#     112     return StatusCode.FAILURE
#
# File ~/git_repos/trig-egamma-frame/trig_egamma_frame/emulator/run3/selector/ringer.py:90, in RingerSelector.initialize(self)
#      88 # Reading all models
#      89 nmodels     = env.GetValue("Model__size", 0)
# ---> 90 barcode_list= treat_float( env, 'Model__barcode' )
#      91 etmin_list  = treat_float( env, 'Model__etmin' )
#      92 etmax_list  = treat_float( env, 'Model__etmax' )
#
# File ~/git_repos/trig-egamma-frame/trig_egamma_frame/emulator/run3/selector/ringer.py:16, in treat_float(env, key)
#      15 def treat_float( env, key ):
# ---> 16   return [float(value) for value in  env.GetValue(key, '').split('; ')]
#
# File ~/git_repos/trig-egamma-frame/trig_egamma_frame/emulator/run3/selector/ringer.py:16, in <listcomp>(.0)
#      15 def treat_float( env, key ):
# ---> 16   return [float(value) for value in  env.GetValue(key, '').split('; ')]
#
# ValueError: could not convert string to float: ''
